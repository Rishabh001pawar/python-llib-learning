# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.set(style = 'darkgrid')

# %%
tips=sns.load_dataset('tips')
tips.head()
# tips.tail()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.relplot(x ='total_bill', y ='tip' ,data = tips)
plt.show(1)

# %%
dir(sns.FacetGrid)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_bottom_axes',
#  '_facet_color',
#  '_facet_plot',
#  '_finalize_grid',
#  '_get_palette',
#  '_inner_axes',
#  '_left_axes',
#  '_legend_out',
#  '_margin_titles',
#  '_not_bottom_axes',
#  '_not_left_axes',
#  '_update_legend_data',
#  'add_legend',
#  'apply',
#  'ax',
#  'axes',
#  'axes_dict',
#  'despine',
#  'facet_axis',
#  'facet_data',
#  'fig',
#  'figure',
#  'legend',
#  'map',
#  'map_dataframe',
#  'pipe',
#  'refline',
#  'savefig',
#  'set',
#  'set_axis_labels',
#  'set_titles',
#  'set_xlabels',
#  'set_xticklabels',
#  'set_ylabels',
#  'set_yticklabels',
#  'tick_params',
#  'tight_layout']

# %%
tips['smoker'].value_counts()
# Out:
# smoker
# No     151
# Yes     93
# Name: count, dtype: int64

# %%
sns.relplot(x='total_bill', y='tip', data=tips, hue='smoker', style='time');
plt.show()

# %%
sns.relplot(x='total_bill', y='tip', hue='size', data=tips);
plt.show()

# %%
sns.relplot(x='total_bill', y='tip', hue='size', data=tips, palette='ch:r=-3.5, l=0.95');
plt.show()

# %%
sns.relplot(x='total_bill', y='tip', data=tips, size='size');
plt.show()

# %%
sns.relplot(x='total_bill', y='tip', style='size', data=tips);
plt.show()

# %%
sns.relplot(x='total_bill', y='tip',  data=tips, size='size', sizes=(30,150));
plt.show()

# %%
from numpy.random import randn

# %%
df = pd.DataFrame(dict(time=np.arange(500),value = randn(500).cumsum()))

# %%
df.head()
# Out:
#    time     value
# 0     0 -0.172022
# 1     1 -0.522357
# 2     2  0.866301
# 3     3  0.995508
# 4     4  0.942048

# %%
sns.relplot(x='time', y='value', kind='line', data=df, sort=True);
plt.show()

# %%
df=pd.DataFrame(randn(500,2).cumsum(axis=0),columns=['time','value'])

# %%
df.head()
# Out:
#        time     value
# 0  0.030888  0.277515
# 1 -0.928537  1.729869
# 2 -1.276693  0.523750
# 3 -2.708255  0.638030
# 4 -1.202073  0.711801

# %%
sns.relplot(x='time', y='value', kind='line', data=df, sort=False);
plt.show()

# %%
fmri=sns.load_dataset('fmri')
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
sns.relplot(x='timepoint', y='signal', kind='line', data=fmri, ci=False);
plt.show()
# Out:
# C:\Users\HP\AppData\Roaming\Python\Python313\site-packages\seaborn\axisgrid.py:854: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   func(*plot_args, **plot_kwargs)

# %%
sns.relplot(x='timepoint', y='signal',estimator=None,kind='line', data=fmri);
plt.show()

# %%
sns.relplot(x='timepoint', y='signal', hue='event',kind='line', data=fmri,);
plt.show()

# %%
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
sns.relplot(x='timepoint', y='signal', hue='region',style='event', kind='line', data=fmri);
plt.show()

# %%
sns.relplot(x='timepoint', y='signal', hue='region',style='event', kind='line', data=fmri, markers=True, dashes=False);
plt.show()

# %%
sns.relplot(x='timepoint', y='signal', hue='event',style='event', kind='line', data=fmri);
plt.show()

# %%
sns.relplot(x='timepoint', y='signal', hue='region',units='subject',estimator=None, kind='line', data=fmri.query("event=='stim'"));
plt.show()

# %%
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
dots=sns.load_dataset('dots').query("align=='dots'")
dots.head()
# Out:
#   align choice  time  coherence  firing_rate
# 0  dots     T1   -80        0.0    33.189967
# 1  dots     T1   -80        3.2    31.691726
# 2  dots     T1   -80        6.4    34.279840
# 3  dots     T1   -80       12.8    32.631874
# 4  dots     T1   -80       25.6    35.060487

# %%
sns.relplot(x='time', y='firing_rate', data=dots, kind='line', hue='coherence', style='choice')
plt.show()

# %%
palette=sns.cubehelix_palette(light=2.8,n_colors=7)
sns.relplot(x='time', y='firing_rate', data=dots, kind='line', hue='coherence', style='choice')
plt.show()

# %%
sns.relplot(x='time', y='firing_rate', data=dots, kind='line', hue='coherence', size='choice', style='choice')
plt.show()

# %%
df = pd.DataFrame(dict(
    time=pd.date_range('2005-09-12', periods=500),
    value=np.random.randn(500).cumsum()
))

# %%
df.head()
# Out:
#         time     value
# 0 2005-09-12  0.814966
# 1 2005-09-13  2.069853
# 2 2005-09-14  1.305260
# 3 2005-09-15  1.265334
# 4 2005-09-16  1.914712

# %%
g=sns.relplot(x='time', y='value', kind='line', data=df);
g.fig.autofmt_xdate()
plt.show()

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.relplot(x='total_bill', y='tip', hue='smoker', col='time', data=tips)
plt.show()

# %%
sns.relplot(x='total_bill', y='tip', hue='smoker', col='size', data=tips)
plt.show()

# %%
# sns.relplot(x='total_bill', y='tip', hue='smoker', row='size', data=tips)
# plt.show()

# %%
sns.relplot(
    x='timepoint', 
    y='signal', 
    hue='subject', 
    col='region', 
    row='event', 
    kind='line', 
    estimator=None, 
    data=fmri
)

plt.show()

# %%
sns.relplot(x='total_bill', 
            y='tip', 
            hue='smoker', 
            col='size',
            data=tips, 
            col_wrap=3,
            height=3)
plt.show()

# %%
# sns.lineplot(x='total_bill', y='tip', data=tips) 
sns.scatterplot(x='total_bill', y='tip', data=tips)
plt.show()

# %%
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
sns.lineplot(x='timepoint' ,
             y='signal',
             style='event',
             data=fmri, 
             hue='region',
            markers=True,
            ci=69,
            err_style='bars')
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_5612\3372714506.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 69)` for the same effect.
#
#   sns.lineplot(x='timepoint' ,

# %%
sns.lineplot(
    x='timepoint',
    y='signal',
    data=fmri.query("region == 'frontal'"), 
    hue='event',
    estimator=None,
    lw=1
)

plt.show()

# %%
dots.head()
# Out:
#   align choice  time  coherence  firing_rate
# 0  dots     T1   -80        0.0    33.189967
# 1  dots     T1   -80        3.2    31.691726
# 2  dots     T1   -80        6.4    34.279840
# 3  dots     T1   -80       12.8    32.631874
# 4  dots     T1   -80       25.6    35.060487

# %%
sns.lineplot(x='time', y='firing_rate',hue='coherence', style='choice', data=dots)
plt.show()

# %%
sns.scatterplot(
    x='total_bill',
    y='tip',
    data=tips,
    hue='smoker',   # fixed
    size='size',    # better to map size to 'size' column
    style='time'    # time has 'Lunch' or 'Dinner'
)

plt.show()

# %%
iris=sns.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.scatterplot(x='sepal_length', y='petal_length', data=iris)
plt.show()

# %%
sns.scatterplot(x=iris['sepal_length'],y=iris['petal_length'])
plt.show()

# %% [markdown]
# ## Categorial Data Ploting
# - catplot()
# - boxplot()
# - stripplot()
# - swarmplot()

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic .head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# # catlpot()

# %%
sns.catplot(x='day', y='total_bill', data=tips)
plt.show()

# %%
sns.catplot(x='day', y='total_bill', data=tips, jitter= False)
plt.show()

# %%
sns.catplot(x='day', y='total_bill', data=tips, kind='swarm', hue='size')
plt.show()

# %%
sns.catplot(x='smoker', y='tip', data=tips, order=['No', 'Yes'])
plt.show()

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.catplot(x='day', y='total_bill', kind='box', data=tips, hue='sex', dodge=False);
plt.show()

# %%
diamonds=sns.load_dataset('diamonds')

# %%
sns.catplot(x='color',y='price',kind='boxen',data=diamonds.sort_values('color'))
plt.show()

# %%
diamonds.sort_values('color')
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
# 7817    1.00  Very Good     D     SI2   63.5   59.0   4295  6.35  6.32  4.02
# 7816    1.00       Good     D     SI2   57.8   58.0   4295  6.61  6.55  3.80
# 7815    1.00  Very Good     D     SI2   61.5   63.0   4295  6.32  6.27  3.87
# 7809    0.56      Ideal     D      IF   61.9   57.0   4293  5.28  5.31  3.28
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 4861    1.00    Premium     J     SI1   60.8   58.0   3712  6.39  6.44  3.90
# 18421   1.52      Ideal     J     SI1   61.9   57.0   7491  7.37  7.33  4.55
# 18423   1.50  Very Good     J     VS2   62.6   58.0   7492  7.25  7.29  4.55
# 42108   0.65      Ideal     J     SI1   61.4   55.0   1276  5.58  5.62  3.44
# 14123   1.30      Ideal     J     SI1   61.5   55.0   5728  7.03  7.06  4.33
#
# [53940 rows x 10 columns]
